# %%
# %pip -q install -U deepagents langchain langchain-core langchain-openai tavily-python langgraph
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.5/108.5 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.2/490.2 kB 19.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.4/157.4 kB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.3/390.3 kB 26.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.1/719.1 kB 33.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 234.9/234.9 kB 15.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.43.0, but you have google-auth 2.47.0 which is incompatible.

# %%
import os
from dotenv import load_dotenv


load_dotenv()

OPENROUTER_API_KEY = os.getenv('OPENROUTER_API_KEY')
TAVILY_API_KEY = os.getenv('TAVILY_API_KEY')
EXA_API_KEY = os.getenv('EXA_API_KEY')

# %%
# !git clone https://github.com/langchain-ai/deepagents.git
# Out:
# Cloning into 'deepagents'...
# remote: Enumerating objects: 11103, done.
# remote: Counting objects: 100% (1713/1713), done.
# remote: Compressing objects: 100% (535/535), done.
# remote: Total 11103 (delta 1520), reused 1178 (delta 1178), pack-reused 9390 (from 4)
# Receiving objects: 100% (11103/11103), 15.06 MiB | 5.07 MiB/s, done.
# Resolving deltas: 100% (6988/6988), done.

# %%
# %cd /content/deepagents/examples/content-builder-agent
# Out:
# /content/deepagents/examples/content-builder-agent

# %%
# %ls
# Out:
# AGENTS.md          pyproject.toml  skills/         uv.lock
# content_writer.py  README.md       subagents.yaml

# %%
# !python content_writer.py "Create a LinkedIn post about AI agents in recruiting in 2026 and how this can be used to automate job writing"
# Out:
# Content Builder Agent
# Task: Create a LinkedIn post about AI agents in recruiting in 2026 and how this
# can be used to automate job writing
#
# ⠋ Thinking...
# ╭──────────────────────────────────── You ─────────────────────────────────────╮
# │ Create a LinkedIn post about AI agents in recruiting in 2026 and how this    │
# │ can be used to automate job writing                                          │
# │                                                                              │
# │ IMPORTANT PATH RULES:                                                        │
# │ - Always use RELATIVE paths (no leading '/').                                │
# │ - For LinkedIn posts: linkedin/<slug>/post.md                                │
# │ - For blog posts: blogs/<slug>/post.md                                       │
# │ - For research: research/<topic>.md                                          │
# │ - For images: <platform>/<slug>/image.png                                    │
# │ - Example: linkedin/ai-recruiting-2026/post.md (NOT /linkedin/... or         │
# │ linkedin//...)                                                               │
# │ - The FilesystemBackend root is already set, so paths should be relative to  │
# │ that root.                                                                   │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ⠇ Thinking...
#
# 📋 Planning Complete - Review Outline
#
# Planned Tasks:
#   ○ 1. Research AI agents in recruiting
#   ○ 2. Draft LinkedIn post content
#   ○ 3. Generate social media image
#   ○ 4. Create LinkedIn post file
#
# Options:
#   approve - Continue with this plan
#   edit - Modify the plan (not yet implemented)
#   reject - Cancel and start over
#
# Your decision (approve/edit/reject): approve
# ╭─────────────────────────────────── Agent ────────────────────────────────────╮
# │ I'll help you create a LinkedIn post about AI agents in recruiting for 2026. │
# │ I'll break this down into steps:                                             │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ⠹ Thinking...
# ⠸ Thinking...
# ╭─────────────────────────────────── Agent ────────────────────────────────────╮
# │ First, I'll use the researcher to gather insights about AI agents in         │
# │ recruiting:                                                                  │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#   >> Researching: Research the future of AI agents in recruiting by 2026,
# focu...
# ⠙ Researching: Research the future of AI agents in recr...
#   ✓ Research complete
# ⠦ Researching: Research the future of AI agents in recr...
#
# 📋 Planning Complete - Review Outline
#
# Planned Tasks:
#   ✓ 1. Research AI agents in recruiting
#   ○ 2. Draft LinkedIn post content
#   ○ 3. Generate social media image
#   ○ 4. Create LinkedIn post file
#
# Options:
#   approve - Continue with this plan
#   edit - Modify the plan (not yet implemented)
#   reject - Cancel and start over
#
# Your decision (approve/edit/reject): approve
# ╭─────────────────────────────────── Agent ────────────────────────────────────╮
# │ Now, I'll mark the research task as completed and move to drafting the post: │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ⠇ Researching: Research the future of AI agents in recr...
# ⠹ Researching: Research the future of AI agents in recr...
# ╭─────────────────────────────────── Agent ────────────────────────────────────╮
# │ I'll draft the LinkedIn post content:                                        │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#   >> Writing: linkedin/ai-recruiting-2026/post.md
# ⠹ Researching: Research the future of AI agents in recr...
#   ✓ File written
# ⠙ Researching: Research the future of AI agents in recr...
# ╭─────────────────────────────────── Agent ────────────────────────────────────╮
# │ I apologize for the error. I'll read the existing file first and then edit   │
# │ it:                                                                          │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ⠹ Researching: Research the future of AI agents in recr...
# ⠧ Researching: Research the future of AI agents in recr...
# ╭─────────────────────────────────── Agent ────────────────────────────────────╮
# │ I'll edit the existing file with our new content:                            │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ⠧ Researching: Research the future of AI agents in recr...
# ⠸ Researching: Research the future of AI agents in recr...
#
# 🖼️  Image Generation Request - generate_social_image
#
# Image Prompt:
# ╭──────────────────────────────────────────────────────────────────────────────╮
# │ Futuristic AI recruitment concept with holographic job descriptions, AI      │
# │ robots and human recruiters collaborating, modern office setting with        │
# │ technology and human elements blending together                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# Platform: linkedin
# Slug: ai-recruiting-2026
#
# Options:
#   approve - Generate image with this prompt
#   edit - Edit the prompt before generating
#   reject - Skip image generation
#
# Your decision (approve/edit/reject): edit
#
# Enter new prompt (or press Enter to keep current):
# Futuristic AI recruitment concept with modern office setting with        │ │ technology and human elements blending together
# ✓ Prompt updated
# ╭─────────────────────────────────── Agent ────────────────────────────────────╮
# │ Now, I'll generate a social media image:                                     │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#   >> Generating image...
# ⠧ Generating image...
#   ✓ Image saved
# ⠧ Generating image...
#
# 📋 Planning Complete - Review Outline
#
# Planned Tasks:
#   ✓ 1. Research AI agents in recruiting
#   ✓ 2. Draft LinkedIn post content
#   ✓ 3. Generate social media image
#   ✓ 4. Create LinkedIn post file
#
# Options:
#   approve - Continue with this plan
#   edit - Modify the plan (not yet implemented)
#   reject - Cancel and start over
#
# Your decision (approve/edit/reject): approve
# ╭─────────────────────────────────── Agent ────────────────────────────────────╮
# │ I'll update the todos to reflect completion:                                 │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ⠹ Generating image...
# ⠙ Generating image...
# ╭─────────────────────────────────── Agent ────────────────────────────────────╮
# │ I've completed your request by:                                              │
# │                                                                              │
# │  1 Researching AI agents in recruiting for 2026                              │
# │  2 Creating a LinkedIn post about AI agents in job writing                   │
# │  3 Generating a social media image for the post                              │
# │                                                                              │
# │ The files are located at:                                                    │
# │                                                                              │
# │  • Post content: linkedin/ai-recruiting-2026/post.md                         │
# │  • Social media image: linkedin/ai-recruiting-2026/image.png                 │
# │                                                                              │
# │ Is there anything else you'd like me to modify about the post?               │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ⠙ Generating image...
#
# ✓ Done!
